# %%
import pandas as pd
# !pip install googletrans-temp
from googletrans import Translator
# Out:
# ...
#   Created wheel for googletrans-temp: filename=googletrans_temp-2.3.0-py3-none-any.whl size=15675 sha256=3d65acf35e07e0853cfcd31f2a2564b5ff2ab07528c802c6bfcb7b31f836da64
#   Stored in directory: /Users/juliasqueri/Library/Caches/pip/wheels/48/c9/ba/2e65fdcd501acfca27578bf026f531afe7001e87101e71f4e5
# Successfully built googletrans-temp
# ...

# %%
csv_file = "Data/RUvideos.csv"

# %%
ru_df = pd.read_csv(csv_file, encoding = "ISO-8859-5")
ru_df.head(5)
# Out:
#       video_id trending_date  \
# 0  gDuslQ9avLc      17.14.11
# 1  AOCJIFEA_jE      17.14.11
# 2  VAWNQDgwwOM      17.14.11
# 3  gknkFwKQfHg      17.14.11
# 4  3sYvZcwzZr8      17.14.11
#
#                                                title       channel_title  \
# 0  ааАб
# аАб аИ ааОаЛаИаНаА ббаАббб баКаО...  аЂта аааааЇ
# 1  ааИбаЖаА ааЕаМаОаВ #29. ааОаЛббаОаИЬ аВ...        Druzhko Show
# 2  аЅааа аа­аа - аЁааа аЁа ааа аЇаЃа...            аЎаЛаИаК
# 3  аЁаОбаНаАб аКаЕбаАаДаИаЛбб б аКббаИбаЕаЙ            Hochland
# 4  аааааЋ а ааааЂаааа аа аЈааааЌа...    аЁаОаВаЕбаГаОаН
#
#    category_id              publish_time  \
# 0           22  2017-11-13T09:09:31.000Z
# 1           22  2017-11-13T17:32:11.000Z
# 2           24  2017-11-13T16:11:31.000Z
# 3           22  2017-11-13T06:51:10.000Z
# 4           24  2017-11-13T16:52:36.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %%
ru_df = ru_df.drop(['video_id','thumbnail_link','ratings_disabled','video_error_or_removed','description'], axis=1)
ru_df
# Out:
#       trending_date                                              title  \
# 0          17.14.11  ааАб
# аАб аИ ааОаЛаИаНаА ббаАббб баКаО...
# 1          17.14.11  ааИбаЖаА ааЕаМаОаВ #29. ааОаЛббаОаИЬ аВ...
# 2          17.14.11  аЅааа аа­аа - аЁааа аЁа ааа аЇаЃа...
# 3          17.14.11  аЁаОбаНаАб аКаЕбаАаДаИаЛбб б аКббаИбаЕаЙ
# 4          17.14.11  аааааЋ а ааааЂаааа аа аЈааааЌа...
# ...             ...                                                ...
# 40734      18.14.06  аЃ аМаЕаНб аЁааа! (Story booth аНаА ббб...
# 40735      18.14.06  ааОаИ ааЕббаКаИаЕ аЂбаАаВаМб 2 (аАаНаИаМ...
# 40736      18.14.06  [ENG SUB] BTS PROM PARTY 2018 Intro + 2nd Gran...
# 40737      18.14.06  ааааа  аааааа ааааааЂаЋ№/аЂа...
# 40738      18.14.06  ааЛаОб
# аОаЙ баИаГаНаАаЛ. аЁбаАаНб баЕаЛаО...
#
#                      channel_title  category_id              publish_time  \
# ...
